# %% [markdown]
# <a href="https://colab.research.google.com/github/FELIPEIDDQD/Arquivos.legais/blob/master/analise_dos_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install pandas 
#import pandas as pd

# %%
#lendo dados da tabela 
import pandas as pd 
#credit = pd.read_csv("/content/credit_card_clients_2.csv")
#credit

# %%
#valores não nulos 
#credit.notnull()

# %%
#valores nulos
#credit.isnull()

# %%
# somando valores nulos 
#credit.isnull().sum()

# %%
# Filtrando os valores nulos
#credit[credit['LIMIT_BAL'].isnull()]

# %%
#excluindo os valores nulos 
#notna()

#credit2 = credit[credit['LIMIT_BAL'].notna()]

# %%
#outra forma de excluir valores nulos 
#dropna() any e all 
credit3 = credit.dropna(how='any')

# %%
# removendo duplicata #drop_duplicates()

# %%
#agrupando dados
#groupby()
#credit_grouped = credit.groupby('EDUCATION').mean().reset_index()
#credit_grouped

# %%
#estatistica descritivas extração 
credit.describe()
# Out:
#                  ID       LIMIT_BAL          SEX     EDUCATION      MARRIAGE  \
# count  30017.000000    30003.000000  30003.00000  30003.000000  30003.000000
# mean   15009.000000   167471.486118      2.60354      2.852948      1.718461
# std     8665.305851   129747.540674    173.18208    173.187526     28.861831
# min        1.000000    10000.000000      1.00000      0.000000      0.000000
# 25%     7505.000000    50000.000000      1.00000      1.000000      1.000000
# 50%    15009.000000   140000.000000      2.00000      2.000000      2.000000
# 75%    22513.000000   240000.000000      2.00000      2.000000      2.000000
# max    30017.000000  1000000.000000  29999.00000  30000.000000   5000.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30003.000000  30003.000000  30003.000000  30003.000000  30003.000000
# mean      35.484252     -0.016665     -0.133687     -0.166150     -0.219111
# ...

# %%
credit[']
